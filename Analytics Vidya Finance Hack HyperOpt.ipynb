# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import lightgbm as lgbm

# %%
# load data
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
sub = pd.read_csv("sample_submission.csv")
train.loan_default.mean() # dist of target var

# %%
# train characteristics
print(train.shape)
train.nunique()

# %%
# missing data
train.isnull().sum()

# %%
# imput missing employment type as missing
train["Employment.Type"]= train["Employment.Type"].fillna("Missing")
test["Employment.Type"]= test["Employment.Type"].fillna("Missing")

# %%
# review dtypes
train.dtypes

# %%
train.head().T

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, PolynomialFeatures

# append test and train sets
train_len = len(train)
merged = pd.concat([train,test],axis=0)
merged.head()

# add date type feats
merged['Date.of.Birth'] = pd.to_datetime(merged['Date.of.Birth'],format="%d-%m-%y")
merged['DisbursalDate'] = pd.to_datetime(merged['DisbursalDate'],format="%d-%m-%y")

# add other date features
merged['dob_year'] = merged['Date.of.Birth'].dt.year
merged['age'] = merged['dob_year'].max() - merged['dob_year']
merged['DD_year']= merged['DisbursalDate'].dt.year

# drop original date feats
merged = merged.drop(['Date.of.Birth','DisbursalDate'],axis=1)

# drop id
merged = merged.drop('UniqueID',axis=1)

# column selector
cat_cols = merged.select_dtypes(include=['object']).columns
num_cols = merged.columns[merged.dtypes!='object'] # select num cols all
num_cols = [c for c in num_cols if c!='UniqueID'] # remove unique ID

# split x and y
X = merged.drop('loan_default',axis=1)
y = merged.loan_default

# label enc cat colsn
# le = LabelEncoder()
# for c in cat_cols:
#    print(c)
#    X[c] = le.fit_transform(X[c])

# one hot
X_dummies = pd.get_dummies(X,columns=cat_cols)

# split out train test sets
train_processed = X_dummies.iloc[:train_len]
test_processed = X_dummies.iloc[train_len:]


# define y in train set only
y = y.iloc[:train_len]

# split train / val
xtrain,xval,ytrain,yval = train_test_split(train_processed,y,test_size=0.2,stratify=y)

print("train len:",len(train_processed))
print("xtrain len:",len(train))
print("train cols:",len(train_processed.columns))
print("xtrain cols:",len(train.columns))

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, PolynomialFeatures

# flag to apply poly feats to analysis
usePoly = True

# append test and train sets
train_len = len(train)
merged = pd.concat([train,test],axis=0)
merged.head()

# add date type feats
merged['Date.of.Birth'] = pd.to_datetime(merged['Date.of.Birth'],format="%d-%m-%y")
merged['DisbursalDate'] = pd.to_datetime(merged['DisbursalDate'],format="%d-%m-%y")

# add other date features
merged['dob_year'] = merged['Date.of.Birth'].dt.year
merged['age'] = merged['dob_year'].max() - merged['dob_year']
merged['DD_year']= merged['DisbursalDate'].dt.year

# drop original date feats
merged = merged.drop(['Date.of.Birth','DisbursalDate'],axis=1)

# drop id
merged = merged.drop('UniqueID',axis=1)

# column selector
cat_cols = merged.select_dtypes(include=['object']).columns
num_cols = merged.columns[merged.dtypes!='object'] # select num cols all
num_cols = [c for c in num_cols if c!='UniqueID'] # remove unique ID

# split x and y
X = merged.drop('loan_default',axis=1)
y = merged.loan_default

# label enc cat colsn
# le = LabelEncoder()
# for c in cat_cols:
#    print(c)
#    X[c] = le.fit_transform(X[c])
    
# one hot
X_dummies = pd.get_dummies(X,columns=cat_cols)

# poly feats
if usePoly == True:
    poly = PolynomialFeatures(include_bias=False,interaction_only=True)
    X_dummies = poly.fit_transform(X_dummies)

# split out train test sets
train_processed = X_dummies.iloc[:train_len]
test_processed = X_dummies.iloc[train_len:]    
    
# define y in train set only
y = y.iloc[:train_len]

# split train / val
xtrain,xval,ytrain,yval = train_test_split(train_processed,y,test_size=0.2,stratify=y)

print("train len:",len(train_processed))
print("xtrain len:",len(train))
print("train cols:",len(train_processed.columns))
print("xtrain cols:",len(train.columns))

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, PolynomialFeatures

# append test and train sets
train_len = len(train)
merged = pd.concat([train,test],axis=0)
merged.head()

# add date type feats
merged['Date.of.Birth'] = pd.to_datetime(merged['Date.of.Birth'],format="%d-%m-%y")
merged['DisbursalDate'] = pd.to_datetime(merged['DisbursalDate'],format="%d-%m-%y")

# add other date features
merged['dob_year'] = merged['Date.of.Birth'].dt.year
merged['age'] = merged['dob_year'].max() - merged['dob_year']
merged['DD_year']= merged['DisbursalDate'].dt.year

# drop original date feats
merged = merged.drop(['Date.of.Birth','DisbursalDate'],axis=1)

# drop id
merged = merged.drop('UniqueID',axis=1)

# column selector
cat_cols = merged.select_dtypes(include=['object']).columns
num_cols = merged.columns[merged.dtypes!='object'] # select num cols all
num_cols = [c for c in num_cols if c!='UniqueID'] # remove unique ID

# split x and y
X = merged.drop('loan_default',axis=1)
y = merged.loan_default

# label enc cat colsn
# le = LabelEncoder()
# for c in cat_cols:
#    print(c)
#    X[c] = le.fit_transform(X[c])
    
# one hot
X_dummies = pd.get_dummies(X,columns=cat_cols)

# split out train test sets
train_processed = X_dummies.iloc[:train_len]
test_processed = X_dummies.iloc[train_len:]

# define y in train set only
y = y.iloc[:train_len]

# split train / val
xtrain,xval,ytrain,yval = train_test_split(train_processed,y,test_size=0.2,stratify=y)

print("train len:",len(train_processed))
print("xtrain len:",len(train))
print("train cols:",len(train_processed.columns))
print("xtrain cols:",len(train.columns))
# Out:
# train len: 233154
# xtrain len: 233154
# train cols: 566
# xtrain cols: 41

# %%
# apply gridseatchcv
from sklearn.model_selection import GridSearchCV, cross_val_score

param_grid = {
    'n_estimators' : [300,400,500],
    'max_depth' : [3,5,7],
    'bagging_fraction' : [0.8],
    'feature_fraction' : [0.7,0.8],
    'num_leaves' : [9,11,13,15]
}

clf = lgbm.LGBMClassifier(class_weight={0:1,1:4})
gridcv = GridSearchCV(clf,param_grid,scoring='roc_auc',n_jobs=1,cv=4, return_train_score=True)
results = gridcv.fit(xtrain,ytrain)
results.best_score_

# %%
### Hyper Opt on LightGBM

from hyperopt import hp, tpe, Trials
from hyperopt.fmin import fmin
from sklearn.metrics import make_scorer
from sklearn.model_selection import KFold, cross_val_score, StratifiedKFold

# the trials object to store details of each iter
trials = Trials()

# define dictionary search space
space = {}

space['n_estimators']= 100 + 100*hp.randint('n_estimators',10)
space['max_depth']= hp.choice('max_depth',np.arange(3,20,dtype=int))
space['num_leaves']= hp.choice('num_leaves', np.arange(2,30,dtype=int))
space['min_data_in_leaf']= hp.choice('min_data_in_leaf', np.arange(20,150,dtype=int))
space['feature_fraction']= hp.uniform('feature_fraction', 0.5,0.9)
space['bagging_fraction']= hp.uniform('bagging_fraction', 0.5,0.9)
space['lambda_l1']= hp.uniform('reg_lambda', 5,30)

# create a counter object
counter = 0
FOLDS= 4
# set objective function
def objective(params):
        global counter
        clf = lgbm.LGBMClassifier(boosting_type='gbdt',
                                  metric='auc',
                                  learning_rate=0.05,
                                  scale_pos_weight=4,
                                  n_jobs=-1)
        clf.set_params(**params)
        # cross val by default uses stratified kfold if no fold object is passed
        score = cross_val_score(clf,xtrain,ytrain,cv=FOLDS,scoring='roc_auc')
        counter +=1
        print("Eval No:",counter,"Score:",1-score.mean(),"Params:",params)
        # cross val score returns ranges of mean and we want to minimize the function hence 1 - metric
        return 1-score.mean()

# %%
# run function to minimize objective

best = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=400,trials=trials,verbose=0)
print("Hyperopt estimated optimum {}".format(best))

# %%
# get best param values
from hyperopt import space_eval
best_params = space_eval(space,best)
print(best_params)
# Out:
# {'bagging_fraction': 0.8938820204303998, 'feature_fraction': 0.8582316318535632, 'lambda_l1': 28.278990042794067, 'max_depth': 16, 'min_data_in_leaf': 90, 'n_estimators': 700, 'num_leaves': 18}

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

best_params = {'bagging_fraction': 0.8830336528248924,
 'feature_fraction': 0.6012577219030728,
 'lambda_l1': 11.304845997489313,
 'max_depth': 10,
 'min_data_in_leaf': 36,
 'n_estimators': 900,
 'num_leaves': 25}

# model
clf = lgbm.LGBMClassifier(**best_params,
                          learning_rate=0.05,
                         scale_pos_weight=4)
clf.fit(xtrain,ytrain)
preds_train = clf.predict(xtrain)
preds = clf.predict(xval)

print("accuracy on train:",roc_auc_score(ytrain,preds_train))
print("accuracy on val:",roc_auc_score(yval,preds))
# Out:
# /home/quan/anaconda3/envs/fastai/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/quan/anaconda3/envs/fastai/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# accuracy on train: 0.6576876872916599
# accuracy on val: 0.6207292586769982

# %%
# use feat importances to see if we can use poly feats on smaller data set
# poly feats

feat_cols = train_processed.columns
feat_imp = clf.feature_importances_

feature_imp_df = pd.DataFrame({'col':feat_cols,'importances':feat_imp})
feature_imp_df = feature_imp_df.sort_values('importances',ascending=False)
cols_for_poly = feature_imp_df.col[:60].values

# apply poly feats
poly = PolynomialFeatures(interaction_only=True)
train_processed_poly= poly.fit_transform(train_processed[cols_for_poly])
test_processed_poly = poly.transform(test_processed[cols_for_poly])

print(len(train_processed.columns))
print((train_processed_poly.shape[1]))

# split train / val
xtrain,xval,ytrain,yval = train_test_split(train_processed_poly,y,test_size=0.2,stratify=y)
# Out:
# 566
# 1831

# %%
print(len(y))
print(train_processed_poly.shape[0])
# Out:
# 233154
# 233154

# %%
# hyperopt for poly feats
counter = 0
FOLDS= 4
def objective_poly(params):
        global counter
        clf = lgbm.LGBMClassifier(boosting_type='gbdt',
                                  metric='auc',
                                  learning_rate=0.05,
                                  scale_pos_weight=4,
                                  n_jobs=-1)
        clf.set_params(**params)
        # cross val by default uses stratified kfold if no fold object is passed
        score = cross_val_score(clf,xtrain,ytrain,cv=FOLDS,scoring='roc_auc')
        counter +=1
        print("Eval No:",counter,"Score:",1-score.mean(),"Params:",params)
        # cross val score returns ranges of mean and we want to minimize the function hence 1 - metric
        return 1-score.mean()

# %%
# run function to minimize objective poly

best = fmin(fn=objective_poly, space=space, algo=tpe.suggest, max_evals=300,trials=trials,verbose=0)
print("Hyperopt estimated optimum {}".format(best))

# get best param values
from hyperopt import space_eval
best_params = space_eval(space,best)
print(best_params)
# Out:
# Eval No: 1 Score: 0.3470315185307199 Params: {'bagging_fraction': 0.8434756212608181, 'feature_fraction': 0.7093820092517485, 'lambda_l1': 5.518617905065938, 'max_depth': 19, 'min_data_in_leaf': 128, 'n_estimators': 200, 'num_leaves': 5}
# Eval No: 2 Score: 0.3403835844639158 Params: {'bagging_fraction': 0.8135705489297143, 'feature_fraction': 0.7865227398625927, 'lambda_l1': 7.0447729809209365, 'max_depth': 8, 'min_data_in_leaf': 137, 'n_estimators': 400, 'num_leaves': 7}
# Eval No: 3 Score: 0.3384318012175753 Params: {'bagging_fraction': 0.7609159893137618, 'feature_fraction': 0.6445596784431933, 'lambda_l1': 28.265225868434204, 'max_depth': 3, 'min_data_in_leaf': 26, 'n_estimators': 600, 'num_leaves': 15}
# Eval No: 4 Score: 0.3363299272188396 Params: {'bagging_fraction': 0.5873485645540982, 'feature_fraction': 0.5460163153466682, 'lambda_l1': 16.872010252925453, 'max_depth': 7, 'min_data_in_leaf': 29, 'n_estimators': 300, 'num_leaves': 28}
# Eval No: 5 Score: 0.3365583672071746 Params: {'bagging_fraction': 0.7057341628303537, 'feature_fraction': 0.8153596689636714, 'lambda_l1': 22.351345852881657, 'max_depth': 11, 'min_data_in_leaf': 56, 'n_estimators': 600, 'num_leaves': 27}
# Eval No: 6 Score: 0.3389740460366162 Params: {'bagging_fraction': 0.6563182570136427, 'feature_fraction': 0.572501807789065, 'lambda_l1': 9.73501330897208, 'max_depth': 19, 'min_data_in_leaf': 130, 'n_estimators': 500, 'num_leaves': 7}
# Eval No: 7 Score: 0.336300495475948 Params: {'bagging_fraction': 0.6331943012784181, 'feature_fraction': 0.5767925286117015, 'lambda_l1': 22.169853184827492, 'max_depth': 4, 'min_data_in_leaf': 83, 'n_estimators': 800, 'num_leaves': 27}
# Eval No: 8 Score: 0.3378295797625176 Params: {'bagging_fraction': 0.7414290553538778, 'feature_fraction': 0.5801215157494586, 'lambda_l1': 6.422109590803491, 'max_depth': 11, 'min_data_in_leaf': 88, 'n_estimators': 200, 'num_leaves': 24}
# Eval No: 9 Score: 0.3369760599646533 Params: {'bagging_fraction': 0.8082486478715993, 'feature_fraction': 0.5750170851912038, 'lambda_l1': 7.271315801320137, 'max_depth': 6, 'min_data_in_leaf': 64, 'n_estimators': 600, 'num_leaves': 14}
# Eval No: 10 Score: 0.3386933828490728 Params: {'bagging_fraction': 0.7354733206077544, 'feature_fraction': 0.5278178409677378, 'lambda_l1': 8.725383031933411, 'max_depth': 4, 'min_data_in_leaf': 121, 'n_estimators': 400, 'num_leaves': 29}
# Eval No: 11 Score: 0.3434934935211398 Params: {'bagging_fraction': 0.6611041824740844, 'feature_fraction': 0.6619883823118966, 'lambda_l1': 21.6000199805039, 'max_depth': 6, 'min_data_in_leaf': 50, 'n_estimators': 100, 'num_leaves': 25}
# Eval No: 12 Score: 0.33915591600017714 Params: {'bagging_fraction': 0.5136567946694113, 'feature_fraction': 0.5009305560867976, 'lambda_l1': 18.926005622885715, 'max_depth': 5, 'min_data_in_leaf': 82, 'n_estimators': 500, 'num_leaves': 7}
# Eval No: 13 Score: 0.3472432486244732 Params: {'bagging_fraction': 0.5991128862060833, 'feature_fraction': 0.7138633213081694, 'lambda_l1': 25.09936375122179, 'max_depth': 5, 'min_data_in_leaf': 138, 'n_estimators': 200, 'num_leaves': 5}
# Eval No: 14 Score: 0.3368897496654719 Params: {'bagging_fraction': 0.5682484112092904, 'feature_fraction': 0.5793067854952357, 'lambda_l1': 13.069649431080583, 'max_depth': 15, 'min_data_in_leaf': 27, 'n_estimators': 500, 'num_leaves': 25}
# Eval No: 15 Score: 0.3366689256824288 Params: {'bagging_fraction': 0.6877589380160706, 'feature_fraction': 0.8302369962652831, 'lambda_l1': 22.94346445990021, 'max_depth': 12, 'min_data_in_leaf': 95, 'n_estimators': 900, 'num_leaves': 21}
# Eval No: 16 Score: 0.335681471498961 Params: {'bagging_fraction': 0.7762156439692731, 'feature_fraction': 0.7272758951129401, 'lambda_l1': 19.535447674615778, 'max_depth': 14, 'min_data_in_leaf': 117, 'n_estimators': 600, 'num_leaves': 14}
# Eval No: 17 Score: 0.33702207974120246 Params: {'bagging_fraction': 0.808097727483658, 'feature_fraction': 0.5674669869453821, 'lambda_l1': 9.40002877860567, 'max_depth': 19, 'min_data_in_leaf': 71, 'n_estimators': 800, 'num_leaves': 11}
# Eval No: 18 Score: 0.33636457314896506 Params: {'bagging_fraction': 0.8379580833467997, 'feature_fraction': 0.6399940726583364, 'lambda_l1': 26.96382855169559, 'max_depth': 17, 'min_data_in_leaf': 62, 'n_estimators': 300, 'num_leaves': 25}
# Eval No: 19 Score: 0.33821629242581697 Params: {'bagging_fraction': 0.5175953651332498, 'feature_fraction': 0.6565115706552769, 'lambda_l1': 9.354757691365936, 'max_depth': 8, 'min_data_in_leaf': 68, 'n_estimators': 400, 'num_leaves': 17}
# Eval No: 20 Score: 0.33790479509933125 Params: {'bagging_fraction': 0.6431801154609158, 'feature_fraction': 0.6960018842014581, 'lambda_l1': 23.350733958699543, 'max_depth': 3, 'min_data_in_leaf': 55, 'n_estimators': 700, 'num_leaves': 14}
# Eval No: 21 Score: 0.3363947557540633 Params: {'bagging_fraction': 0.8787426993979811, 'feature_fraction': 0.7718676795742527, 'lambda_l1': 17.02359828437959, 'max_depth': 14, 'min_data_in_leaf': 117, 'n_estimators': 800, 'num_leaves': 10}
# Eval No: 22 Score: 0.3361135987724423 Params: {'bagging_fraction': 0.620630412964993, 'feature_fraction': 0.7460467073626981, 'lambda_l1': 19.393921621147268, 'max_depth': 4, 'min_data_in_leaf': 83, 'n_estimators': 1000, 'num_leaves': 27}
# Eval No: 23 Score: 0.33643515432706494 Params: {'bagging_fraction': 0.7115625993343923, 'feature_fraction': 0.8622163925542095, 'lambda_l1': 13.171163842875359, 'max_depth': 14, 'min_data_in_leaf': 106, 'n_estimators': 1000, 'num_leaves': 12}
# Eval No: 24 Score: 0.34116926135454395 Params: {'bagging_fraction': 0.5482182014025532, 'feature_fraction': 0.7476180908637877, 'lambda_l1': 19.218228942168682, 'max_depth': 13, 'min_data_in_leaf': 61, 'n_estimators': 1000, 'num_leaves': 3}
# Eval No: 25 Score: 0.3365515386139293 Params: {'bagging_fraction': 0.7708800278169594, 'feature_fraction': 0.7394728461772272, 'lambda_l1': 14.645217669840793, 'max_depth': 9, 'min_data_in_leaf': 23, 'n_estimators': 1000, 'num_leaves': 18}
# Eval No: 26 Score: 0.3352736514415222 Params: {'bagging_fraction': 0.8924976616113236, 'feature_fraction': 0.8465591919384046, 'lambda_l1': 19.979535387727424, 'max_depth': 18, 'min_data_in_leaf': 69, 'n_estimators': 700, 'num_leaves': 16}
# Eval No: 27 Score: 0.3355927579690454 Params: {'bagging_fraction': 0.8820647631866929, 'feature_fraction': 0.8937822108218342, 'lambda_l1': 26.10606525841696, 'max_depth': 18, 'min_data_in_leaf': 135, 'n_estimators': 700, 'num_leaves': 16}
# Eval No: 28 Score: 0.3356414907232941 Params: {'bagging_fraction': 0.8988228048606481, 'feature_fraction': 0.8995688076616393, 'lambda_l1': 28.94047744642492, 'max_depth': 18, 'min_data_in_leaf': 135, 'n_estimators': 700, 'num_leaves': 16}
# Eval No: 29 Score: 0.3356442009801225 Params: {'bagging_fraction': 0.8750337392538803, 'feature_fraction': 0.8783492118822346, 'lambda_l1': 25.959415545625852, 'max_depth': 18, 'min_data_in_leaf': 69, 'n_estimators': 700, 'num_leaves': 16}
# Eval No: 30 Score: 0.3357142452036874 Params: {'bagging_fraction': 0.8540278617329798, 'feature_fraction': 0.8469491735795032, 'lambda_l1': 24.6518372073546, 'max_depth': 18, 'min_data_in_leaf': 39, 'n_estimators': 700, 'num_leaves': 16}
# Eval No: 31 Score: 0.35156618196259637 Params: {'bagging_fraction': 0.8985530780310576, 'feature_fraction': 0.7989463389216666, 'lambda_l1': 29.73554750234603, 'max_depth': 10, 'min_data_in_leaf': 120, 'n_estimators': 700, 'num_leaves': 2}
# Eval No: 32 Score: 0.33602989678201145 Params: {'bagging_fraction': 0.8309948015754479, 'feature_fraction': 0.8937455082171988, 'lambda_l1': 27.99136356388714, 'max_depth': 18, 'min_data_in_leaf': 81, 'n_estimators': 700, 'num_leaves': 23}
# Eval No: 33 Score: 0.336202844347134 Params: {'bagging_fraction': 0.8595326444124367, 'feature_fraction': 0.8648690218881377, 'lambda_l1': 20.859858542874555, 'max_depth': 16, 'min_data_in_leaf': 25, 'n_estimators': 900, 'num_leaves': 19}
# Eval No: 34 Score: 0.3426450904408983 Params: {'bagging_fraction': 0.7892466861207499, 'feature_fraction': 0.7758445838055444, 'lambda_l1': 15.689195121363461, 'max_depth': 18, 'min_data_in_leaf': 101, 'n_estimators': 100, 'num_leaves': 20}
# Eval No: 35 Score: 0.3366823003628068 Params: {'bagging_fraction': 0.8954972722846943, 'feature_fraction': 0.8208587040604387, 'lambda_l1': 26.98825140322708, 'max_depth': 7, 'min_data_in_leaf': 113, 'n_estimators': 700, 'num_leaves': 9}
# Eval No: 36 Score: 0.338231107072251 Params: {'bagging_fraction': 0.8768444860989949, 'feature_fraction': 0.79957567786391, 'lambda_l1': 24.343241893579687, 'max_depth': 16, 'min_data_in_leaf': 69, 'n_estimators': 300, 'num_leaves': 13}
# Eval No: 37 Score: 0.3379513470929978 Params: {'bagging_fraction': 0.8306117863313051, 'feature_fraction': 0.842553701403856, 'lambda_l1': 12.281089696889872, 'max_depth': 17, 'min_data_in_leaf': 98, 'n_estimators': 700, 'num_leaves': 8}
# Eval No: 38 Score: 0.3393622050809477 Params: {'bagging_fraction': 0.7984552985593789, 'feature_fraction': 0.8979393851055729, 'lambda_l1': 20.42593687471716, 'max_depth': 18, 'min_data_in_leaf': 79, 'n_estimators': 200, 'num_leaves': 15}
# Eval No: 39 Score: 0.33690855235343986 Params: {'bagging_fraction': 0.736639657804447, 'feature_fraction': 0.6115884552999303, 'lambda_l1': 15.659904347386963, 'max_depth': 9, 'min_data_in_leaf': 70, 'n_estimators': 900, 'num_leaves': 26}
# Eval No: 40 Score: 0.3574650411280209 Params: {'bagging_fraction': 0.7557927596722125, 'feature_fraction': 0.6929633617093314, 'lambda_l1': 17.420134285576832, 'max_depth': 15, 'min_data_in_leaf': 37, 'n_estimators': 100, 'num_leaves': 4}
# Eval No: 41 Score: 0.34072358875066144 Params: {'bagging_fraction': 0.6774905808039434, 'feature_fraction': 0.8756950901178906, 'lambda_l1': 18.108047703479166, 'max_depth': 11, 'min_data_in_leaf': 48, 'n_estimators': 400, 'num_leaves': 6}
# Eval No: 42 Score: 0.3360884272774153 Params: {'bagging_fraction': 0.7099480367670619, 'feature_fraction': 0.7643240937847404, 'lambda_l1': 23.65621362650113, 'max_depth': 10, 'min_data_in_leaf': 85, 'n_estimators': 700, 'num_leaves': 28}
# Eval No: 43 Score: 0.3356195664852155 Params: {'bagging_fraction': 0.8260949090369042, 'feature_fraction': 0.8022772409792438, 'lambda_l1': 25.888627695542176, 'max_depth': 12, 'min_data_in_leaf': 77, 'n_estimators': 600, 'num_leaves': 22}
# Eval No: 44 Score: 0.33665127365532455 Params: {'bagging_fraction': 0.8558370067089174, 'feature_fraction': 0.8569501151681834, 'lambda_l1': 11.186986215076281, 'max_depth': 13, 'min_data_in_leaf': 78, 'n_estimators': 500, 'num_leaves': 16}
# Eval No: 45 Score: 0.33629223842227796 Params: {'bagging_fraction': 0.7552004043146974, 'feature_fraction': 0.8286754476576114, 'lambda_l1': 29.957449986052865, 'max_depth': 8, 'min_data_in_leaf': 135, 'n_estimators': 300, 'num_leaves': 29}
# Eval No: 46 Score: 0.33968472217247614 Params: {'bagging_fraction': 0.790850574150892, 'feature_fraction': 0.6144458898107302, 'lambda_l1': 22.39133932450583, 'max_depth': 6, 'min_data_in_leaf': 143, 'n_estimators': 200, 'num_leaves': 16}
# Eval No: 47 Score: 0.3388757146859489 Params: {'bagging_fraction': 0.818578593454435, 'feature_fraction': 0.8774123485552757, 'lambda_l1': 21.70895406544878, 'max_depth': 3, 'min_data_in_leaf': 109, 'n_estimators': 800, 'num_leaves': 5}
# Eval No: 48 Score: 0.33606315926455876 Params: {'bagging_fraction': 0.722407335152798, 'feature_fraction': 0.7129737097364515, 'lambda_l1': 27.371485293881506, 'max_depth': 19, 'min_data_in_leaf': 38, 'n_estimators': 700, 'num_leaves': 24}
# Eval No: 49 Score: 0.33694635938452655 Params: {'bagging_fraction': 0.884330676393354, 'feature_fraction': 0.8434771298742081, 'lambda_l1': 20.340917933818965, 'max_depth': 5, 'min_data_in_leaf': 84, 'n_estimators': 400, 'num_leaves': 16}
# Eval No: 50 Score: 0.3389349739314824 Params: {'bagging_fraction': 0.8591394958467301, 'feature_fraction': 0.8130413663667848, 'lambda_l1': 25.761775872414617, 'max_depth': 7, 'min_data_in_leaf': 53, 'n_estimators': 500, 'num_leaves': 7}
# Eval No: 51 Score: 0.33633077220012353 Params: {'bagging_fraction': 0.6908012812165951, 'feature_fraction': 0.6852748182023027, 'lambda_l1': 16.060930757579438, 'max_depth': 18, 'min_data_in_leaf': 42, 'n_estimators': 600, 'num_leaves': 21}
# Eval No: 52 Score: 0.34706669028886095 Params: {'bagging_fraction': 0.588341095287927, 'feature_fraction': 0.5245133108567683, 'lambda_l1': 28.78592124429076, 'max_depth': 11, 'min_data_in_leaf': 66, 'n_estimators': 100, 'num_leaves': 11}
# Eval No: 53 Score: 0.3367958877530898 Params: {'bagging_fraction': 0.6129212185599469, 'feature_fraction': 0.6767122848624887, 'lambda_l1': 14.36236551990038, 'max_depth': 4, 'min_data_in_leaf': 100, 'n_estimators': 900, 'num_leaves': 17}
# Eval No: 54 Score: 0.33679107420328447 Params: {'bagging_fraction': 0.5018729620786077, 'feature_fraction': 0.7803958840937628, 'lambda_l1': 18.429384209426868, 'max_depth': 15, 'min_data_in_leaf': 86, 'n_estimators': 700, 'num_leaves': 10}
# Eval No: 55 Score: 0.3378692779065817 Params: {'bagging_fraction': 0.6668022678228306, 'feature_fraction': 0.7224484351799121, 'lambda_l1': 7.097228367716568, 'max_depth': 18, 'min_data_in_leaf': 47, 'n_estimators': 800, 'num_leaves': 18}
# Eval No: 56 Score: 0.3403920478293573 Params: {'bagging_fraction': 0.8444350041945499, 'feature_fraction': 0.7632752299718485, 'lambda_l1': 24.00740779042923, 'max_depth': 12, 'min_data_in_leaf': 34, 'n_estimators': 200, 'num_leaves': 12}
# Eval No: 57 Score: 0.33776202344073236 Params: {'bagging_fraction': 0.8878407857836337, 'feature_fraction': 0.8881618087465445, 'lambda_l1': 5.2292813360663, 'max_depth': 17, 'min_data_in_leaf': 115, 'n_estimators': 300, 'num_leaves': 19}
# Eval No: 58 Score: 0.34351633618353883 Params: {'bagging_fraction': 0.5383514657160506, 'feature_fraction': 0.5003691406509556, 'lambda_l1': 22.791275224395093, 'max_depth': 6, 'min_data_in_leaf': 43, 'n_estimators': 700, 'num_leaves': 3}
# Eval No: 59 Score: 0.3484022500351347 Params: {'bagging_fraction': 0.7734853320586377, 'feature_fraction': 0.6158551460773773, 'lambda_l1': 25.26326958920346, 'max_depth': 3, 'min_data_in_leaf': 131, 'n_estimators': 1000, 'num_leaves': 2}
# Eval No: 60 Score: 0.33580248712701954 Params: {'bagging_fraction': 0.8132380700524038, 'feature_fraction': 0.7915013226574292, 'lambda_l1': 21.820550062369428, 'max_depth': 8, 'min_data_in_leaf': 20, 'n_estimators': 400, 'num_leaves': 23}
# Eval No: 61 Score: 0.3375167626522577 Params: {'bagging_fraction': 0.8669955730630542, 'feature_fraction': 0.8370986373809955, 'lambda_l1': 8.089771631412967, 'max_depth': 5, 'min_data_in_leaf': 122, 'n_estimators': 500, 'num_leaves': 20}
# Eval No: 62 Score: 0.33662558453654445 Params: {'bagging_fraction': 0.6461753601663272, 'feature_fraction': 0.8155089935910126, 'lambda_l1': 20.852693848222525, 'max_depth': 19, 'min_data_in_leaf': 52, 'n_estimators': 700, 'num_leaves': 9}
# Eval No: 63 Score: 0.3373500076228463 Params: {'bagging_fraction': 0.7247363556133554, 'feature_fraction': 0.7322420032840529, 'lambda_l1': 10.736384308409853, 'max_depth': 13, 'min_data_in_leaf': 133, 'n_estimators': 700, 'num_leaves': 27}
# Eval No: 64 Score: 0.3389422183400713 Params: {'bagging_fraction': 0.843367803341494, 'feature_fraction': 0.7557334204212081, 'lambda_l1': 19.88467858891172, 'max_depth': 14, 'min_data_in_leaf': 74, 'n_estimators': 600, 'num_leaves': 6}
# Eval No: 65 Score: 0.35722376440822146 Params: {'bagging_fraction': 0.8016123587997523, 'feature_fraction': 0.8576327465398086, 'lambda_l1': 6.1700758925558965, 'max_depth': 18, 'min_data_in_leaf': 139, 'n_estimators': 100, 'num_leaves': 4}
# Eval No: 66 Score: 0.3361534820945554 Params: {'bagging_fraction': 0.8976052743302753, 'feature_fraction': 0.8093769405348671, 'lambda_l1': 26.497682660311845, 'max_depth': 12, 'min_data_in_leaf': 46, 'n_estimators': 600, 'num_leaves': 13}
# Eval No: 67 Score: 0.3375220377399878 Params: {'bagging_fraction': 0.8249837147768602, 'feature_fraction': 0.888896623795596, 'lambda_l1': 28.295185329269838, 'max_depth': 9, 'min_data_in_leaf': 60, 'n_estimators': 600, 'num_leaves': 8}
# Eval No: 68 Score: 0.33559819537075397 Params: {'bagging_fraction': 0.8660530837229741, 'feature_fraction': 0.7912980825724598, 'lambda_l1': 24.849906530194037, 'max_depth': 12, 'min_data_in_leaf': 142, 'n_estimators': 600, 'num_leaves': 22}
# Eval No: 69 Score: 0.3357265180727709 Params: {'bagging_fraction': 0.8700304075219595, 'feature_fraction': 0.7881983068484695, 'lambda_l1': 24.92793058322534, 'max_depth': 12, 'min_data_in_leaf': 49, 'n_estimators': 600, 'num_leaves': 22}
# Eval No: 70 Score: 0.3357456111730972 Params: {'bagging_fraction': 0.8414685051568616, 'feature_fraction': 0.8718429982810558, 'lambda_l1': 23.374066795974773, 'max_depth': 16, 'min_data_in_leaf': 144, 'n_estimators': 600, 'num_leaves': 22}
# Eval No: 71 Score: 0.335358093758098 Params: {'bagging_fraction': 0.8825845396616837, 'feature_fraction': 0.8226190903132873, 'lambda_l1': 29.599634078311574, 'max_depth': 10, 'min_data_in_leaf': 142, 'n_estimators': 900, 'num_leaves': 15}
# Eval No: 72 Score: 0.3353557350556007 Params: {'bagging_fraction': 0.7839899685120512, 'feature_fraction': 0.8520696810508658, 'lambda_l1': 29.680351969963514, 'max_depth': 10, 'min_data_in_leaf': 132, 'n_estimators': 900, 'num_leaves': 16}
# Eval No: 73 Score: 0.33563615827324234 Params: {'bagging_fraction': 0.7869259443790222, 'feature_fraction': 0.8301678714313936, 'lambda_l1': 29.302019158671886, 'max_depth': 10, 'min_data_in_leaf': 132, 'n_estimators': 900, 'num_leaves': 14}
# Eval No: 74 Score: 0.33539058982917114 Params: {'bagging_fraction': 0.764418116030254, 'feature_fraction': 0.8511372723456923, 'lambda_l1': 27.996583979981118, 'max_depth': 10, 'min_data_in_leaf': 57, 'n_estimators': 900, 'num_leaves': 15}
# Eval No: 75 Score: 0.33529521917551797 Params: {'bagging_fraction': 0.7803561729876524, 'feature_fraction': 0.8250673499741044, 'lambda_l1': 26.942762311057102, 'max_depth': 10, 'min_data_in_leaf': 111, 'n_estimators': 900, 'num_leaves': 15}
# Eval No: 76 Score: 0.3368140576137333 Params: {'bagging_fraction': 0.7533689435830419, 'feature_fraction': 0.8640068596821334, 'lambda_l1': 27.289691758210214, 'max_depth': 10, 'min_data_in_leaf': 111, 'n_estimators': 900, 'num_leaves': 26}
# Eval No: 77 Score: 0.33738508692432156 Params: {'bagging_fraction': 0.7428029545823029, 'feature_fraction': 0.7403941838251415, 'lambda_l1': 16.647798723285604, 'max_depth': 10, 'min_data_in_leaf': 110, 'n_estimators': 900, 'num_leaves': 28}
# Eval No: 78 Score: 0.33766462732542535 Params: {'bagging_fraction': 0.6928931846630857, 'feature_fraction': 0.706705552454385, 'lambda_l1': 14.363624469064607, 'max_depth': 7, 'min_data_in_leaf': 111, 'n_estimators': 900, 'num_leaves': 25}
# Eval No: 79 Score: 0.33600588290471556 Params: {'bagging_fraction': 0.7800449386930782, 'feature_fraction': 0.8832550577511015, 'lambda_l1': 18.68748648163569, 'max_depth': 10, 'min_data_in_leaf': 124, 'n_estimators': 900, 'num_leaves': 15}
# Eval No: 80 Score: 0.33678214798276784 Params: {'bagging_fraction': 0.6789140296024323, 'feature_fraction': 0.7709303457118207, 'lambda_l1': 13.451655218000242, 'max_depth': 4, 'min_data_in_leaf': 91, 'n_estimators': 900, 'num_leaves': 16}
# Eval No: 81 Score: 0.33873998540730166 Params: {'bagging_fraction': 0.7283805174233156, 'feature_fraction': 0.6510168832352803, 'lambda_l1': 17.81239536393875, 'max_depth': 10, 'min_data_in_leaf': 40, 'n_estimators': 800, 'num_leaves': 5}
# Eval No: 82 Score: 0.3357700279275345 Params: {'bagging_fraction': 0.7471413221156004, 'feature_fraction': 0.6675051714389408, 'lambda_l1': 26.63817778023475, 'max_depth': 11, 'min_data_in_leaf': 149, 'n_estimators': 1000, 'num_leaves': 16}
# Eval No: 83 Score: 0.336497948903292 Params: {'bagging_fraction': 0.7010396493012482, 'feature_fraction': 0.7535764304053548, 'lambda_l1': 21.17617946455823, 'max_depth': 15, 'min_data_in_leaf': 76, 'n_estimators': 900, 'num_leaves': 21}
# Eval No: 84 Score: 0.33620007102833294 Params: {'bagging_fraction': 0.8044119794108594, 'feature_fraction': 0.8057827548218794, 'lambda_l1': 28.481575044258367, 'max_depth': 17, 'min_data_in_leaf': 41, 'n_estimators': 300, 'num_leaves': 29}
# Eval No: 85 Score: 0.34439002253017814 Params: {'bagging_fraction': 0.7933886457279085, 'feature_fraction': 0.6349062056424795, 'lambda_l1': 27.68260431676865, 'max_depth': 14, 'min_data_in_leaf': 146, 'n_estimators': 200, 'num_leaves': 7}
# Eval No: 86 Score: 0.33646266100192146 Params: {'bagging_fraction': 0.6255240516895086, 'feature_fraction': 0.8993694553440787, 'lambda_l1': 29.973603144508573, 'max_depth': 10, 'min_data_in_leaf': 129, 'n_estimators': 400, 'num_leaves': 24}
# Eval No: 87 Score: 0.3356101803472026 Params: {'bagging_fraction': 0.7808610517001588, 'feature_fraction': 0.8702217049265459, 'lambda_l1': 24.06377369751877, 'max_depth': 9, 'min_data_in_leaf': 148, 'n_estimators': 900, 'num_leaves': 17}
# Eval No: 88 Score: 0.3371665794371762 Params: {'bagging_fraction': 0.7173079342177657, 'feature_fraction': 0.850797624949176, 'lambda_l1': 22.27640214491548, 'max_depth': 8, 'min_data_in_leaf': 44, 'n_estimators': 500, 'num_leaves': 10}
# Eval No: 89 Score: 0.35211930930731283 Params: {'bagging_fraction': 0.7612439549584447, 'feature_fraction': 0.8381925306728002, 'lambda_l1': 22.96945613104604, 'max_depth': 3, 'min_data_in_leaf': 36, 'n_estimators': 100, 'num_leaves': 11}
# Eval No: 90 Score: 0.335311666073861 Params: {'bagging_fraction': 0.8191139590115546, 'feature_fraction': 0.599104548999638, 'lambda_l1': 25.5561088550741, 'max_depth': 6, 'min_data_in_leaf': 132, 'n_estimators': 800, 'num_leaves': 12}
# Eval No: 91 Score: 0.33567813663552215 Params: {'bagging_fraction': 0.8499137672934286, 'feature_fraction': 0.5893237277038305, 'lambda_l1': 25.349757108225504, 'max_depth': 6, 'min_data_in_leaf': 123, 'n_estimators': 800, 'num_leaves': 12}
# Eval No: 92 Score: 0.3431666058024502 Params: {'bagging_fraction': 0.8160392653550017, 'feature_fraction': 0.5545362136343883, 'lambda_l1': 19.82562778467737, 'max_depth': 6, 'min_data_in_leaf': 69, 'n_estimators': 800, 'num_leaves': 3}
# Eval No: 93 Score: 0.33549191434357706 Params: {'bagging_fraction': 0.8342900240852936, 'feature_fraction': 0.5883579149809384, 'lambda_l1': 19.223668712451712, 'max_depth': 6, 'min_data_in_leaf': 126, 'n_estimators': 800, 'num_leaves': 15}
# Eval No: 94 Score: 0.3359301115005279 Params: {'bagging_fraction': 0.7676938726319084, 'feature_fraction': 0.5243317306426262, 'lambda_l1': 16.944250456512684, 'max_depth': 13, 'min_data_in_leaf': 80, 'n_estimators': 800, 'num_leaves': 12}
# Eval No: 95 Score: 0.33613952053604457 Params: {'bagging_fraction': 0.8080496632431695, 'feature_fraction': 0.6303110453068644, 'lambda_l1': 15.149273641946326, 'max_depth': 6, 'min_data_in_leaf': 145, 'n_estimators': 800, 'num_leaves': 12}
# Eval No: 96 Score: 0.3487912263508851 Params: {'bagging_fraction': 0.8904001227302305, 'feature_fraction': 0.5133695440565211, 'lambda_l1': 24.414118520731805, 'max_depth': 19, 'min_data_in_leaf': 22, 'n_estimators': 1000, 'num_leaves': 2}
# Eval No: 97 Score: 0.3379537726643079 Params: {'bagging_fraction': 0.8266832935843894, 'feature_fraction': 0.5433455865409756, 'lambda_l1': 22.775452414800554, 'max_depth': 5, 'min_data_in_leaf': 51, 'n_estimators': 300, 'num_leaves': 18}
# Eval No: 98 Score: 0.3380984624527026 Params: {'bagging_fraction': 0.7340650404172563, 'feature_fraction': 0.5667765486063573, 'lambda_l1': 21.321507872652827, 'max_depth': 16, 'min_data_in_leaf': 54, 'n_estimators': 200, 'num_leaves': 20}
# Eval No: 99 Score: 0.33614778368967935 Params: {'bagging_fraction': 0.8513038007747862, 'feature_fraction': 0.7216218711278817, 'lambda_l1': 26.37126039621475, 'max_depth': 18, 'min_data_in_leaf': 73, 'n_estimators': 400, 'num_leaves': 19}
# Eval No: 100 Score: 0.3360366020135793 Params: {'bagging_fraction': 0.8226003372155073, 'feature_fraction': 0.6029528455235972, 'lambda_l1': 22.05276913543402, 'max_depth': 4, 'min_data_in_leaf': 105, 'n_estimators': 800, 'num_leaves': 23}
# Eval No: 101 Score: 0.33646155922908616 Params: {'bagging_fraction': 0.7734995678486578, 'feature_fraction': 0.6654833128769844, 'lambda_l1': 25.375255364376375, 'max_depth': 11, 'min_data_in_leaf': 93, 'n_estimators': 700, 'num_leaves': 9}
# Eval No: 102 Score: 0.33563311243203653 Params: {'bagging_fraction': 0.8368601189950747, 'feature_fraction': 0.6962201399050764, 'lambda_l1': 28.915097795441483, 'max_depth': 7, 'min_data_in_leaf': 45, 'n_estimators': 500, 'num_leaves': 27}
# Eval No: 103 Score: 0.3408895895544707 Params: {'bagging_fraction': 0.8756354774850303, 'feature_fraction': 0.6274534128642562, 'lambda_l1': 26.956403569458324, 'max_depth': 6, 'min_data_in_leaf': 24, 'n_estimators': 700, 'num_leaves': 4}
# Eval No: 104 Score: 0.34509418549910353 Params: {'bagging_fraction': 0.794308626315966, 'feature_fraction': 0.6798584662965972, 'lambda_l1': 20.434840048644663, 'max_depth': 15, 'min_data_in_leaf': 134, 'n_estimators': 100, 'num_leaves': 13}
# Eval No: 105 Score: 0.3366465899949129 Params: {'bagging_fraction': 0.6507189678930659, 'feature_fraction': 0.6012394063594382, 'lambda_l1': 16.39756132829683, 'max_depth': 17, 'min_data_in_leaf': 125, 'n_estimators': 800, 'num_leaves': 8}
# Eval No: 106 Score: 0.34296937134251515 Params: {'bagging_fraction': 0.8668746801654298, 'feature_fraction': 0.6465741607486083, 'lambda_l1': 23.46585424903405, 'max_depth': 18, 'min_data_in_leaf': 59, 'n_estimators': 300, 'num_leaves': 6}
# Eval No: 107 Score: 0.3396891263403349 Params: {'bagging_fraction': 0.5694102373042937, 'feature_fraction': 0.5453558463414245, 'lambda_l1': 11.570828991021038, 'max_depth': 8, 'min_data_in_leaf': 112, 'n_estimators': 1000, 'num_leaves': 26}
# Eval No: 108 Score: 0.33944271099184087 Params: {'bagging_fraction': 0.6673096108746013, 'feature_fraction': 0.7774369251175621, 'lambda_l1': 18.212397602612903, 'max_depth': 14, 'min_data_in_leaf': 30, 'n_estimators': 200, 'num_leaves': 14}
# Eval No: 109 Score: 0.33836240385349803 Params: {'bagging_fraction': 0.8114542916270633, 'feature_fraction': 0.7058595979447785, 'lambda_l1': 17.284431230201005, 'max_depth': 3, 'min_data_in_leaf': 119, 'n_estimators': 700, 'num_leaves': 25}
# Eval No: 110 Score: 0.3359162059065849 Params: {'bagging_fraction': 0.8600050805840287, 'feature_fraction': 0.7329271677106742, 'lambda_l1': 26.025972497758342, 'max_depth': 13, 'min_data_in_leaf': 99, 'n_estimators': 400, 'num_leaves': 28}
# Eval No: 111 Score: 0.3369790745409895 Params: {'bagging_fraction': 0.7133087085114306, 'feature_fraction': 0.5092396993259842, 'lambda_l1': 13.69978752898081, 'max_depth': 19, 'min_data_in_leaf': 96, 'n_estimators': 500, 'num_leaves': 12}
# Eval No: 112 Score: 0.3356845636326551 Params: {'bagging_fraction': 0.7529313118160741, 'feature_fraction': 0.5622183629428517, 'lambda_l1': 18.82955306822853, 'max_depth': 9, 'min_data_in_leaf': 92, 'n_estimators': 800, 'num_leaves': 15}
# Eval No: 113 Score: 0.34440530261280955 Params: {'bagging_fraction': 0.7994869225276455, 'feature_fraction': 0.8220038211686751, 'lambda_l1': 27.57482318480985, 'max_depth': 5, 'min_data_in_leaf': 58, 'n_estimators': 100, 'num_leaves': 29}
# Eval No: 114 Score: 0.339859229986466 Params: {'bagging_fraction': 0.8945766473274793, 'feature_fraction': 0.7978215719439705, 'lambda_l1': 10.117145362277705, 'max_depth': 16, 'min_data_in_leaf': 107, 'n_estimators': 700, 'num_leaves': 5}
# Eval No: 115 Score: 0.3361221148961855 Params: {'bagging_fraction': 0.8467487541281538, 'feature_fraction': 0.6562055391878626, 'lambda_l1': 24.010497943651146, 'max_depth': 6, 'min_data_in_leaf': 65, 'n_estimators': 1000, 'num_leaves': 21}
# Eval No: 116 Score: 0.3413432286994962 Params: {'bagging_fraction': 0.7316163214590307, 'feature_fraction': 0.5803371453289787, 'lambda_l1': 29.25229502985174, 'max_depth': 18, 'min_data_in_leaf': 87, 'n_estimators': 300, 'num_leaves': 7}
# Eval No: 117 Score: 0.3419339329333593 Params: {'bagging_fraction': 0.7043767073890348, 'feature_fraction': 0.764227934399522, 'lambda_l1': 17.712938048578685, 'max_depth': 4, 'min_data_in_leaf': 90, 'n_estimators': 200, 'num_leaves': 24}
# Eval No: 118 Score: 0.3358483609040125 Params: {'bagging_fraction': 0.743196270057598, 'feature_fraction': 0.5380908968929261, 'lambda_l1': 20.108508881075416, 'max_depth': 11, 'min_data_in_leaf': 33, 'n_estimators': 800, 'num_leaves': 17}
# Eval No: 119 Score: 0.33607248537726164 Params: {'bagging_fraction': 0.8310788130728183, 'feature_fraction': 0.6228973755226838, 'lambda_l1': 20.69782544481032, 'max_depth': 15, 'min_data_in_leaf': 108, 'n_estimators': 700, 'num_leaves': 11}
# Eval No: 120 Score: 0.3420327403481205 Params: {'bagging_fraction': 0.6831843216879493, 'feature_fraction': 0.6870490200939205, 'lambda_l1': 12.16461377514949, 'max_depth': 18, 'min_data_in_leaf': 89, 'n_estimators': 900, 'num_leaves': 3}
# Eval No: 121 Score: 0.338098245901324 Params: {'bagging_fraction': 0.8812939209694445, 'feature_fraction': 0.7476578746843418, 'lambda_l1': 24.558470335409073, 'max_depth': 17, 'min_data_in_leaf': 102, 'n_estimators': 400, 'num_leaves': 10}
# Eval No: 122 Score: 0.34359405376536234 Params: {'bagging_fraction': 0.7658490179772849, 'feature_fraction': 0.8155683731494633, 'lambda_l1': 15.075209861899616, 'max_depth': 7, 'min_data_in_leaf': 72, 'n_estimators': 100, 'num_leaves': 18}
# Eval No: 123 Score: 0.33668535230231433 Params: {'bagging_fraction': 0.8999416190670245, 'feature_fraction': 0.7842751790511971, 'lambda_l1': 25.582370053155806, 'max_depth': 6, 'min_data_in_leaf': 63, 'n_estimators': 500, 'num_leaves': 12}
# Eval No: 124 Score: 0.33602616374503547 Params: {'bagging_fraction': 0.8191973091141883, 'feature_fraction': 0.6393899683876713, 'lambda_l1': 21.49226252243993, 'max_depth': 14, 'min_data_in_leaf': 94, 'n_estimators': 800, 'num_leaves': 15}
# Eval No: 125 Score: 0.3377211023908744 Params: {'bagging_fraction': 0.8584864651480268, 'feature_fraction': 0.7201844696783597, 'lambda_l1': 28.326352935809822, 'max_depth': 3, 'min_data_in_leaf': 147, 'n_estimators': 700, 'num_leaves': 19}
# Eval No: 126 Score: 0.3486153558046923 Params: {'bagging_fraction': 0.6928735959887596, 'feature_fraction': 0.8404489778197701, 'lambda_l1': 22.94296566683294, 'max_depth': 9, 'min_data_in_leaf': 35, 'n_estimators': 900, 'num_leaves': 2}
# Eval No: 127 Score: 0.3374245055074143 Params: {'bagging_fraction': 0.6072738703812891, 'feature_fraction': 0.889377506305442, 'lambda_l1': 22.021459765508173, 'max_depth': 8, 'min_data_in_leaf': 103, 'n_estimators': 1000, 'num_leaves': 23}
# Eval No: 128 Score: 0.3362805494096922 Params: {'bagging_fraction': 0.7205352207026676, 'feature_fraction': 0.8265670460063528, 'lambda_l1': 19.535019705076515, 'max_depth': 12, 'min_data_in_leaf': 114, 'n_estimators': 600, 'num_leaves': 16}
# Eval No: 129 Score: 0.3402536612545325 Params: {'bagging_fraction': 0.6358026029197839, 'feature_fraction': 0.7570618153239784, 'lambda_l1': 8.281450538625215, 'max_depth': 13, 'min_data_in_leaf': 97, 'n_estimators': 300, 'num_leaves': 9}
# Eval No: 130 Score: 0.3366916907586702 Params: {'bagging_fraction': 0.7764687489889707, 'feature_fraction': 0.6719880611807016, 'lambda_l1': 26.812937352843743, 'max_depth': 10, 'min_data_in_leaf': 21, 'n_estimators': 900, 'num_leaves': 27}
# Eval No: 131 Score: 0.33579500868118206 Params: {'bagging_fraction': 0.7873986673295597, 'feature_fraction': 0.8792052615054299, 'lambda_l1': 27.88235888568708, 'max_depth': 19, 'min_data_in_leaf': 136, 'n_estimators': 800, 'num_leaves': 20}
# Eval No: 132 Score: 0.3356760139209066 Params: {'bagging_fraction': 0.8367860681844141, 'feature_fraction': 0.6025384695949215, 'lambda_l1': 22.46398564882254, 'max_depth': 5, 'min_data_in_leaf': 67, 'n_estimators': 700, 'num_leaves': 26}
# Eval No: 133 Score: 0.34019614190405645 Params: {'bagging_fraction': 0.8732600509568507, 'feature_fraction': 0.8641739782573651, 'lambda_l1': 23.639241610162617, 'max_depth': 18, 'min_data_in_leaf': 104, 'n_estimators': 200, 'num_leaves': 13}
# Eval No: 134 Score: 0.3368736700486138 Params: {'bagging_fraction': 0.8061912406927456, 'feature_fraction': 0.5313621097713804, 'lambda_l1': 15.9346260315689, 'max_depth': 16, 'min_data_in_leaf': 32, 'n_estimators': 400, 'num_leaves': 14}
# Eval No: 135 Score: 0.34303054574322855 Params: {'bagging_fraction': 0.8918961992322259, 'feature_fraction': 0.7421502490447823, 'lambda_l1': 12.775009088738955, 'max_depth': 6, 'min_data_in_leaf': 127, 'n_estimators': 500, 'num_leaves': 4}
# Eval No: 136 Score: 0.33727388783451606 Params: {'bagging_fraction': 0.7491117793310479, 'feature_fraction': 0.7982222249762119, 'lambda_l1': 24.872949926903402, 'max_depth': 7, 'min_data_in_leaf': 28, 'n_estimators': 900, 'num_leaves': 28}
# Eval No: 137 Score: 0.3365540218688837 Params: {'bagging_fraction': 0.8159309924214002, 'feature_fraction': 0.7284423565224565, 'lambda_l1': 27.220206404966735, 'max_depth': 10, 'min_data_in_leaf': 138, 'n_estimators': 800, 'num_leaves': 8}
# Eval No: 138 Score: 0.3471571114223615 Params: {'bagging_fraction': 0.6687500597574911, 'feature_fraction': 0.7701232091782686, 'lambda_l1': 20.945660679635786, 'max_depth': 4, 'min_data_in_leaf': 75, 'n_estimators': 100, 'num_leaves': 25}
# Eval No: 139 Score: 0.3383125820249634 Params: {'bagging_fraction': 0.5217132965716802, 'feature_fraction': 0.8998004363080756, 'lambda_l1': 26.402404762244153, 'max_depth': 11, 'min_data_in_leaf': 128, 'n_estimators': 700, 'num_leaves': 6}
# Eval No: 140 Score: 0.33641031130831744 Params: {'bagging_fraction': 0.7598804012944979, 'feature_fraction': 0.5906127645983646, 'lambda_l1': 29.19524578042069, 'max_depth': 18, 'min_data_in_leaf': 137, 'n_estimators': 600, 'num_leaves': 12}
# Eval No: 141 Score: 0.33596164013900665 Params: {'bagging_fraction': 0.8421623816781068, 'feature_fraction': 0.8335456863346516, 'lambda_l1': 19.142873884762157, 'max_depth': 15, 'min_data_in_leaf': 130, 'n_estimators': 900, 'num_leaves': 15}
# Eval No: 142 Score: 0.33760275491592096 Params: {'bagging_fraction': 0.7389423358055304, 'feature_fraction': 0.5753702934671838, 'lambda_l1': 25.806609738722738, 'max_depth': 6, 'min_data_in_leaf': 82, 'n_estimators': 1000, 'num_leaves': 29}
# Eval No: 143 Score: 0.33581903462742924 Params: {'bagging_fraction': 0.8634918739153316, 'feature_fraction': 0.5529370535313384, 'lambda_l1': 29.913486847457207, 'max_depth': 12, 'min_data_in_leaf': 31, 'n_estimators': 800, 'num_leaves': 16}
# Eval No: 144 Score: 0.33650817497367425 Params: {'bagging_fraction': 0.8539245983716597, 'feature_fraction': 0.8099993505809566, 'lambda_l1': 28.630968490773405, 'max_depth': 8, 'min_data_in_leaf': 132, 'n_estimators': 300, 'num_leaves': 22}
# Eval No: 145 Score: 0.3392585091465714 Params: {'bagging_fraction': 0.792152532904934, 'feature_fraction': 0.6584273007051874, 'lambda_l1': 23.248565429802163, 'max_depth': 17, 'min_data_in_leaf': 27, 'n_estimators': 700, 'num_leaves': 5}
# Eval No: 146 Score: 0.3356671683141865 Params: {'bagging_fraction': 0.7815125786574627, 'feature_fraction': 0.8573556717008088, 'lambda_l1': 29.538569489682363, 'max_depth': 10, 'min_data_in_leaf': 132, 'n_estimators': 900, 'num_leaves': 16}
# Eval No: 147 Score: 0.33553327779308806 Params: {'bagging_fraction': 0.8037769118241938, 'feature_fraction': 0.8493277902495197, 'lambda_l1': 28.156083040937368, 'max_depth': 10, 'min_data_in_leaf': 140, 'n_estimators': 900, 'num_leaves': 16}
# Eval No: 148 Score: 0.33584210667034486 Params: {'bagging_fraction': 0.8238299703984585, 'feature_fraction': 0.8811261315837571, 'lambda_l1': 25.27380601886699, 'max_depth': 10, 'min_data_in_leaf': 95, 'n_estimators': 900, 'num_leaves': 16}
# Eval No: 149 Score: 0.3357162265490239 Params: {'bagging_fraction': 0.783655647698536, 'feature_fraction': 0.8465972501001646, 'lambda_l1': 24.01951496181746, 'max_depth': 10, 'min_data_in_leaf': 64, 'n_estimators': 900, 'num_leaves': 16}
# Eval No: 150 Score: 0.33677419937321096 Params: {'bagging_fraction': 0.769959773505721, 'feature_fraction': 0.8734562405998467, 'lambda_l1': 27.299023787831544, 'max_depth': 10, 'min_data_in_leaf': 26, 'n_estimators': 900, 'num_leaves': 24}
# Eval No: 151 Score: 0.3368027803355903 Params: {'bagging_fraction': 0.7969211301471218, 'feature_fraction': 0.8691217869440199, 'lambda_l1': 24.81511358753973, 'max_depth': 10, 'min_data_in_leaf': 141, 'n_estimators': 900, 'num_leaves': 7}
# Eval No: 152 Score: 0.3357074302879848 Params: {'bagging_fraction': 0.7263520583490669, 'feature_fraction': 0.79103671906956, 'lambda_l1': 28.804905891791154, 'max_depth': 14, 'min_data_in_leaf': 116, 'n_estimators': 900, 'num_leaves': 11}
# Eval No: 153 Score: 0.34536789374765775 Params: {'bagging_fraction': 0.7094587672513992, 'feature_fraction': 0.8553742097823078, 'lambda_l1': 26.74300545890995, 'max_depth': 3, 'min_data_in_leaf': 111, 'n_estimators': 200, 'num_leaves': 17}
# Eval No: 154 Score: 0.33606527098184236 Params: {'bagging_fraction': 0.7555704437608939, 'feature_fraction': 0.8906576969265093, 'lambda_l1': 29.763810187106618, 'max_depth': 9, 'min_data_in_leaf': 68, 'n_estimators': 400, 'num_leaves': 21}
# Eval No: 155 Score: 0.33613808286267743 Params: {'bagging_fraction': 0.8290561754997203, 'feature_fraction': 0.8336982110442838, 'lambda_l1': 27.54813093032813, 'max_depth': 13, 'min_data_in_leaf': 55, 'n_estimators': 900, 'num_leaves': 10}
# Eval No: 156 Score: 0.33692167752400803 Params: {'bagging_fraction': 0.6974817110074623, 'feature_fraction': 0.8176513473144982, 'lambda_l1': 29.964849959330863, 'max_depth': 5, 'min_data_in_leaf': 101, 'n_estimators': 500, 'num_leaves': 12}
# Eval No: 157 Score: 0.33608172057027164 Params: {'bagging_fraction': 0.8115688498873098, 'feature_fraction': 0.8053158545656508, 'lambda_l1': 26.027664671926107, 'max_depth': 19, 'min_data_in_leaf': 81, 'n_estimators': 800, 'num_leaves': 15}
# Eval No: 158 Score: 0.3624137937765445 Params: {'bagging_fraction': 0.8465640609694702, 'feature_fraction': 0.7783237277958077, 'lambda_l1': 24.286563927992532, 'max_depth': 18, 'min_data_in_leaf': 29, 'n_estimators': 100, 'num_leaves': 3}
# Eval No: 159 Score: 0.33535802172149043 Params: {'bagging_fraction': 0.8774883717295915, 'feature_fraction': 0.843006486845222, 'lambda_l1': 27.930102713170974, 'max_depth': 16, 'min_data_in_leaf': 88, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 160 Score: 0.3363205647490034 Params: {'bagging_fraction': 0.7739767400756885, 'feature_fraction': 0.8641278397635793, 'lambda_l1': 18.32563635551831, 'max_depth': 6, 'min_data_in_leaf': 56, 'n_estimators': 900, 'num_leaves': 19}
# Eval No: 161 Score: 0.3517966230530608 Params: {'bagging_fraction': 0.6586436043409083, 'feature_fraction': 0.6989059753241018, 'lambda_l1': 21.659884003896725, 'max_depth': 10, 'min_data_in_leaf': 118, 'n_estimators': 600, 'num_leaves': 2}
# Eval No: 162 Score: 0.33599431656972434 Params: {'bagging_fraction': 0.7477444208936298, 'feature_fraction': 0.8296332856188571, 'lambda_l1': 29.115058197308517, 'max_depth': 4, 'min_data_in_leaf': 106, 'n_estimators': 1000, 'num_leaves': 16}
# Eval No: 163 Score: 0.33579541749648223 Params: {'bagging_fraction': 0.8890945192971332, 'feature_fraction': 0.7837561515032776, 'lambda_l1': 26.288381233726792, 'max_depth': 7, 'min_data_in_leaf': 132, 'n_estimators': 800, 'num_leaves': 23}
# Eval No: 164 Score: 0.33985571139102677 Params: {'bagging_fraction': 0.7352430338005149, 'feature_fraction': 0.8991619991179631, 'lambda_l1': 22.647965570937764, 'max_depth': 11, 'min_data_in_leaf': 69, 'n_estimators': 300, 'num_leaves': 9}
# Eval No: 165 Score: 0.33626154945972186 Params: {'bagging_fraction': 0.8380535039873004, 'feature_fraction': 0.7963203620397828, 'lambda_l1': 15.416832892443665, 'max_depth': 18, 'min_data_in_leaf': 121, 'n_estimators': 700, 'num_leaves': 13}
# Eval No: 166 Score: 0.34296587666584843 Params: {'bagging_fraction': 0.7639289844095797, 'feature_fraction': 0.8831073039440156, 'lambda_l1': 13.889789134955201, 'max_depth': 10, 'min_data_in_leaf': 113, 'n_estimators': 200, 'num_leaves': 8}
# Eval No: 167 Score: 0.3358140615283265 Params: {'bagging_fraction': 0.8686970311487278, 'feature_fraction': 0.7148335571894899, 'lambda_l1': 20.09993681680136, 'max_depth': 6, 'min_data_in_leaf': 84, 'n_estimators': 900, 'num_leaves': 20}
# Eval No: 168 Score: 0.3410722806257839 Params: {'bagging_fraction': 0.7900313970374997, 'feature_fraction': 0.7585368412213599, 'lambda_l1': 16.515927010665223, 'max_depth': 15, 'min_data_in_leaf': 38, 'n_estimators': 400, 'num_leaves': 6}
# Eval No: 169 Score: 0.3376387491331603 Params: {'bagging_fraction': 0.8179903387374126, 'feature_fraction': 0.6197682838169086, 'lambda_l1': 6.193622962552979, 'max_depth': 9, 'min_data_in_leaf': 39, 'n_estimators': 500, 'num_leaves': 14}
# Eval No: 170 Score: 0.33610899663690486 Params: {'bagging_fraction': 0.8997887475275421, 'feature_fraction': 0.7508768998509082, 'lambda_l1': 23.50986553581606, 'max_depth': 17, 'min_data_in_leaf': 48, 'n_estimators': 800, 'num_leaves': 26}
# Eval No: 171 Score: 0.3363100973342785 Params: {'bagging_fraction': 0.7180482958117411, 'feature_fraction': 0.5120351067351323, 'lambda_l1': 28.520511970023676, 'max_depth': 14, 'min_data_in_leaf': 78, 'n_estimators': 900, 'num_leaves': 25}
# Eval No: 172 Score: 0.34158187148297714 Params: {'bagging_fraction': 0.8012782105823958, 'feature_fraction': 0.8241643763291959, 'lambda_l1': 25.538072474822997, 'max_depth': 12, 'min_data_in_leaf': 61, 'n_estimators': 100, 'num_leaves': 27}
# Eval No: 173 Score: 0.34073787941809264 Params: {'bagging_fraction': 0.6868328465528262, 'feature_fraction': 0.7359115982088738, 'lambda_l1': 26.915640366921586, 'max_depth': 8, 'min_data_in_leaf': 71, 'n_estimators': 700, 'num_leaves': 4}
# Eval No: 174 Score: 0.3366644273258039 Params: {'bagging_fraction': 0.8313758650918406, 'feature_fraction': 0.609423847942687, 'lambda_l1': 17.711712864473302, 'max_depth': 13, 'min_data_in_leaf': 25, 'n_estimators': 600, 'num_leaves': 12}
# Eval No: 175 Score: 0.33609752163068585 Params: {'bagging_fraction': 0.8558042972132892, 'feature_fraction': 0.6850045747232465, 'lambda_l1': 14.727856079190786, 'max_depth': 10, 'min_data_in_leaf': 120, 'n_estimators': 900, 'num_leaves': 15}
# Eval No: 176 Score: 0.3370969470978734 Params: {'bagging_fraction': 0.5659846393299325, 'feature_fraction': 0.7683428899328838, 'lambda_l1': 22.2208481592547, 'max_depth': 3, 'min_data_in_leaf': 77, 'n_estimators': 1000, 'num_leaves': 28}
# Eval No: 177 Score: 0.3359167328169175 Params: {'bagging_fraction': 0.8117398791478719, 'feature_fraction': 0.8125008718693748, 'lambda_l1': 25.04467177319829, 'max_depth': 19, 'min_data_in_leaf': 117, 'n_estimators': 800, 'num_leaves': 16}
# Eval No: 178 Score: 0.3366566317416597 Params: {'bagging_fraction': 0.8820249146308351, 'feature_fraction': 0.858696242472453, 'lambda_l1': 17.130085652038183, 'max_depth': 18, 'min_data_in_leaf': 143, 'n_estimators': 300, 'num_leaves': 22}
# Eval No: 179 Score: 0.3377536971140077 Params: {'bagging_fraction': 0.6765910086423197, 'feature_fraction': 0.8391463071512728, 'lambda_l1': 9.97936369873358, 'max_depth': 6, 'min_data_in_leaf': 83, 'n_estimators': 700, 'num_leaves': 29}
# Eval No: 180 Score: 0.337786935593815 Params: {'bagging_fraction': 0.7812982747862641, 'feature_fraction': 0.8936885462675976, 'lambda_l1': 21.14552368509781, 'max_depth': 16, 'min_data_in_leaf': 34, 'n_estimators': 200, 'num_leaves': 21}
# Eval No: 181 Score: 0.3382143910827664 Params: {'bagging_fraction': 0.7603681900752549, 'feature_fraction': 0.8066430037059221, 'lambda_l1': 24.48435275525461, 'max_depth': 5, 'min_data_in_leaf': 43, 'n_estimators': 900, 'num_leaves': 5}
# Eval No: 182 Score: 0.33624955698692194 Params: {'bagging_fraction': 0.7425466498139691, 'feature_fraction': 0.8746070999335195, 'lambda_l1': 29.979833149441387, 'max_depth': 10, 'min_data_in_leaf': 37, 'n_estimators': 400, 'num_leaves': 16}
# Eval No: 183 Score: 0.3389724942490644 Params: {'bagging_fraction': 0.7973354897810663, 'feature_fraction': 0.6476352576573464, 'lambda_l1': 20.510869284596055, 'max_depth': 7, 'min_data_in_leaf': 23, 'n_estimators': 500, 'num_leaves': 7}
# Eval No: 184 Score: 0.33623084415970306 Params: {'bagging_fraction': 0.8453207221421503, 'feature_fraction': 0.5004821289812554, 'lambda_l1': 19.556190493773357, 'max_depth': 4, 'min_data_in_leaf': 62, 'n_estimators': 800, 'num_leaves': 24}
# Eval No: 185 Score: 0.33617309152069164 Params: {'bagging_fraction': 0.701520658813682, 'feature_fraction': 0.5558261897183232, 'lambda_l1': 23.863000094861334, 'max_depth': 11, 'min_data_in_leaf': 70, 'n_estimators': 700, 'num_leaves': 10}
# Eval No: 186 Score: 0.33578639626368867 Params: {'bagging_fraction': 0.8632693961780885, 'feature_fraction': 0.638670379479183, 'lambda_l1': 18.69990083765448, 'max_depth': 18, 'min_data_in_leaf': 42, 'n_estimators': 900, 'num_leaves': 17}
# Eval No: 187 Score: 0.3469785325063437 Params: {'bagging_fraction': 0.7253295759449132, 'feature_fraction': 0.8498744064888728, 'lambda_l1': 23.184201197901235, 'max_depth': 6, 'min_data_in_leaf': 98, 'n_estimators': 100, 'num_leaves': 11}
# Eval No: 188 Score: 0.33710518408065415 Params: {'bagging_fraction': 0.851696455087236, 'feature_fraction': 0.8196640300419802, 'lambda_l1': 10.7688626635221, 'max_depth': 15, 'min_data_in_leaf': 50, 'n_estimators': 600, 'num_leaves': 12}
# Eval No: 189 Score: 0.3356839381113491 Params: {'bagging_fraction': 0.6394126072520665, 'feature_fraction': 0.5941175753650852, 'lambda_l1': 27.712837711938043, 'max_depth': 10, 'min_data_in_leaf': 85, 'n_estimators': 900, 'num_leaves': 15}
# Eval No: 190 Score: 0.335680006880001 Params: {'bagging_fraction': 0.8231728766283226, 'feature_fraction': 0.7755573085597359, 'lambda_l1': 26.31949945415656, 'max_depth': 17, 'min_data_in_leaf': 79, 'n_estimators': 800, 'num_leaves': 16}
# Eval No: 191 Score: 0.35052389468440137 Params: {'bagging_fraction': 0.7693433007300344, 'feature_fraction': 0.70241604351093, 'lambda_l1': 29.389790454015547, 'max_depth': 8, 'min_data_in_leaf': 132, 'n_estimators': 300, 'num_leaves': 3}
# Eval No: 192 Score: 0.33612175066091665 Params: {'bagging_fraction': 0.7867026727252749, 'feature_fraction': 0.7892964714897736, 'lambda_l1': 28.343036719977167, 'max_depth': 12, 'min_data_in_leaf': 109, 'n_estimators': 1000, 'num_leaves': 18}
# Eval No: 193 Score: 0.35105550752982717 Params: {'bagging_fraction': 0.7526799195255981, 'feature_fraction': 0.5834668167858436, 'lambda_l1': 25.768430518053954, 'max_depth': 3, 'min_data_in_leaf': 66, 'n_estimators': 700, 'num_leaves': 2}
# Eval No: 194 Score: 0.34226119098225705 Params: {'bagging_fraction': 0.7130141101470332, 'feature_fraction': 0.673321856650022, 'lambda_l1': 21.839889961990973, 'max_depth': 14, 'min_data_in_leaf': 53, 'n_estimators': 200, 'num_leaves': 9}
# Eval No: 195 Score: 0.3354498274335127 Params: {'bagging_fraction': 0.8067277319889778, 'feature_fraction': 0.7146530598130328, 'lambda_l1': 29.008950273566327, 'max_depth': 9, 'min_data_in_leaf': 111, 'n_estimators': 900, 'num_leaves': 13}
# Eval No: 196 Score: 0.3355044977058014 Params: {'bagging_fraction': 0.8701173706856372, 'feature_fraction': 0.8021054748464987, 'lambda_l1': 27.06559125615251, 'max_depth': 10, 'min_data_in_leaf': 115, 'n_estimators': 400, 'num_leaves': 23}
# Eval No: 197 Score: 0.3367965478329389 Params: {'bagging_fraction': 0.8999042414140866, 'feature_fraction': 0.5690457413684776, 'lambda_l1': 8.71760561770319, 'max_depth': 18, 'min_data_in_leaf': 49, 'n_estimators': 500, 'num_leaves': 19}
# Eval No: 198 Score: 0.3377238820524382 Params: {'bagging_fraction': 0.6236832674139139, 'feature_fraction': 0.8325313451907648, 'lambda_l1': 22.803825854878426, 'max_depth': 13, 'min_data_in_leaf': 133, 'n_estimators': 800, 'num_leaves': 27}
# Eval No: 199 Score: 0.33788584061619786 Params: {'bagging_fraction': 0.8361147929803979, 'feature_fraction': 0.8636927540906285, 'lambda_l1': 12.571019022713525, 'max_depth': 19, 'min_data_in_leaf': 131, 'n_estimators': 900, 'num_leaves': 6}
# ...
# Eval No: 237 Score: 0.34562715330274996 Params: {'bagging_fraction': 0.8680050434003727, 'feature_fraction': 0.5198447542376342, 'lambda_l1': 14.85861212282274, 'max_depth': 3, 'min_data_in_leaf': 126, 'n_estimators': 200, 'num_leaves': 26}
# Eval No: 238 Score: 0.3365377021728768 Params: {'bagging_fraction': 0.7948946311842607, 'feature_fraction': 0.8584783539833011, 'lambda_l1': 24.680223453284583, 'max_depth': 18, 'min_data_in_leaf': 102, 'n_estimators': 400, 'num_leaves': 16}
# Eval No: 239 Score: 0.3366935273024739 Params: {'bagging_fraction': 0.5354003743482004, 'feature_fraction': 0.6785906443276373, 'lambda_l1': 20.244862142275306, 'max_depth': 13, 'min_data_in_leaf': 96, 'n_estimators': 800, 'num_leaves': 15}
# Eval No: 240 Score: 0.33582335194365476 Params: {'bagging_fraction': 0.8064508145860764, 'feature_fraction': 0.5755675521263801, 'lambda_l1': 21.31178565130066, 'max_depth': 9, 'min_data_in_leaf': 22, 'n_estimators': 500, 'num_leaves': 25}
# Eval No: 241 Score: 0.3381283422460146 Params: {'bagging_fraction': 0.6625941352877727, 'feature_fraction': 0.8426195957065352, 'lambda_l1': 15.41346199975446, 'max_depth': 19, 'min_data_in_leaf': 24, 'n_estimators': 900, 'num_leaves': 28}
# Eval No: 242 Score: 0.33567812997248936 Params: {'bagging_fraction': 0.8793327939203679, 'feature_fraction': 0.7868700293708721, 'lambda_l1': 27.704179520646672, 'max_depth': 5, 'min_data_in_leaf': 125, 'n_estimators': 700, 'num_leaves': 29}
# Eval No: 243 Score: 0.3438035542632346 Params: {'bagging_fraction': 0.8999718850178116, 'feature_fraction': 0.8792343236619032, 'lambda_l1': 29.46009641717695, 'max_depth': 6, 'min_data_in_leaf': 30, 'n_estimators': 100, 'num_leaves': 22}
# Eval No: 244 Score: 0.33886799475561735 Params: {'bagging_fraction': 0.7770731696625393, 'feature_fraction': 0.7241780193272801, 'lambda_l1': 9.521625886367536, 'max_depth': 16, 'min_data_in_leaf': 112, 'n_estimators': 900, 'num_leaves': 5}
# Eval No: 245 Score: 0.3355936401991745 Params: {'bagging_fraction': 0.7617347926298215, 'feature_fraction': 0.8187982651150814, 'lambda_l1': 22.415173920254702, 'max_depth': 10, 'min_data_in_leaf': 58, 'n_estimators': 600, 'num_leaves': 16}
# Eval No: 246 Score: 0.33583568325291313 Params: {'bagging_fraction': 0.8540036520035249, 'feature_fraction': 0.7567020516884491, 'lambda_l1': 19.766447853118205, 'max_depth': 7, 'min_data_in_leaf': 107, 'n_estimators': 800, 'num_leaves': 21}
# Eval No: 247 Score: 0.3358800462826701 Params: {'bagging_fraction': 0.7110541114575718, 'feature_fraction': 0.8871391176826844, 'lambda_l1': 28.550394110972324, 'max_depth': 18, 'min_data_in_leaf': 93, 'n_estimators': 1000, 'num_leaves': 17}
# Eval No: 248 Score: 0.3361271456309787 Params: {'bagging_fraction': 0.7902563860399097, 'feature_fraction': 0.6452633533575138, 'lambda_l1': 22.96621790789403, 'max_depth': 4, 'min_data_in_leaf': 119, 'n_estimators': 700, 'num_leaves': 24}
# Eval No: 249 Score: 0.3414794323412814 Params: {'bagging_fraction': 0.8620153710955086, 'feature_fraction': 0.8000958094328567, 'lambda_l1': 29.933697034911088, 'max_depth': 11, 'min_data_in_leaf': 33, 'n_estimators': 300, 'num_leaves': 7}
# Eval No: 250 Score: 0.33581181910351976 Params: {'bagging_fraction': 0.8162096706413998, 'feature_fraction': 0.8719476406880327, 'lambda_l1': 20.694341888234774, 'max_depth': 6, 'min_data_in_leaf': 92, 'n_estimators': 900, 'num_leaves': 12}
# Eval No: 251 Score: 0.33949321916071207 Params: {'bagging_fraction': 0.8881586513132635, 'feature_fraction': 0.7820434539501179, 'lambda_l1': 18.3434797964995, 'max_depth': 10, 'min_data_in_leaf': 72, 'n_estimators': 200, 'num_leaves': 15}
# Eval No: 252 Score: 0.33591134800831635 Params: {'bagging_fraction': 0.8019598952835969, 'feature_fraction': 0.8535173142135376, 'lambda_l1': 23.60720371792025, 'max_depth': 15, 'min_data_in_leaf': 87, 'n_estimators': 800, 'num_leaves': 10}
# Eval No: 253 Score: 0.3382597190729115 Params: {'bagging_fraction': 0.5703206466590827, 'feature_fraction': 0.5055030164840395, 'lambda_l1': 14.258216984099015, 'max_depth': 17, 'min_data_in_leaf': 65, 'n_estimators': 400, 'num_leaves': 11}
# Eval No: 254 Score: 0.33599240125615926 Params: {'bagging_fraction': 0.6137616839081843, 'feature_fraction': 0.698847622096706, 'lambda_l1': 25.45213882857529, 'max_depth': 14, 'min_data_in_leaf': 32, 'n_estimators': 500, 'num_leaves': 18}
# Eval No: 255 Score: 0.3357726103139598 Params: {'bagging_fraction': 0.8312724975279379, 'feature_fraction': 0.7651562554670267, 'lambda_l1': 26.268660717683122, 'max_depth': 8, 'min_data_in_leaf': 67, 'n_estimators': 900, 'num_leaves': 16}
# Eval No: 256 Score: 0.3370944148561559 Params: {'bagging_fraction': 0.6456801855802263, 'feature_fraction': 0.8268225109420023, 'lambda_l1': 16.40891918526015, 'max_depth': 12, 'min_data_in_leaf': 108, 'n_estimators': 700, 'num_leaves': 9}
# Eval No: 257 Score: 0.34191070049684646 Params: {'bagging_fraction': 0.7265768346116191, 'feature_fraction': 0.8941843275186462, 'lambda_l1': 27.006003279105805, 'max_depth': 10, 'min_data_in_leaf': 63, 'n_estimators': 900, 'num_leaves': 3}
# Eval No: 258 Score: 0.3353379127961572 Params: {'bagging_fraction': 0.8761117299529845, 'feature_fraction': 0.8393341310178062, 'lambda_l1': 28.303955731122702, 'max_depth': 16, 'min_data_in_leaf': 89, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 259 Score: 0.33586824147846295 Params: {'bagging_fraction': 0.8733099198269025, 'feature_fraction': 0.8438155278539988, 'lambda_l1': 27.936107383609475, 'max_depth': 16, 'min_data_in_leaf': 114, 'n_estimators': 700, 'num_leaves': 23}
# Eval No: 260 Score: 0.3355086420316826 Params: {'bagging_fraction': 0.8447530579917056, 'feature_fraction': 0.8349976887293987, 'lambda_l1': 28.886450249064325, 'max_depth': 16, 'min_data_in_leaf': 103, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 261 Score: 0.33573567320541753 Params: {'bagging_fraction': 0.8757801603614599, 'feature_fraction': 0.8126258242692265, 'lambda_l1': 27.415709023412933, 'max_depth': 16, 'min_data_in_leaf': 111, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 262 Score: 0.33498652263450157 Params: {'bagging_fraction': 0.8938820204303998, 'feature_fraction': 0.8582316318535632, 'lambda_l1': 28.278990042794067, 'max_depth': 16, 'min_data_in_leaf': 90, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 263 Score: 0.33548623090483254 Params: {'bagging_fraction': 0.8976829273150752, 'feature_fraction': 0.8605716866398225, 'lambda_l1': 26.6643439263868, 'max_depth': 16, 'min_data_in_leaf': 136, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 264 Score: 0.33548629276955166 Params: {'bagging_fraction': 0.894925973599793, 'feature_fraction': 0.8662354418819218, 'lambda_l1': 24.870157457192732, 'max_depth': 16, 'min_data_in_leaf': 90, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 265 Score: 0.33516652689404103 Params: {'bagging_fraction': 0.8873090955710272, 'feature_fraction': 0.8039811756715346, 'lambda_l1': 28.148566562340083, 'max_depth': 16, 'min_data_in_leaf': 89, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 266 Score: 0.3353029250620142 Params: {'bagging_fraction': 0.8861685322244091, 'feature_fraction': 0.8215309509036034, 'lambda_l1': 25.780801855819714, 'max_depth': 16, 'min_data_in_leaf': 90, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 267 Score: 0.3351256111316224 Params: {'bagging_fraction': 0.8847431901254728, 'feature_fraction': 0.8036737548869782, 'lambda_l1': 29.154235561987058, 'max_depth': 16, 'min_data_in_leaf': 90, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 268 Score: 0.3354040072269113 Params: {'bagging_fraction': 0.8926063894123797, 'feature_fraction': 0.802792441947467, 'lambda_l1': 29.970136760139567, 'max_depth': 16, 'min_data_in_leaf': 134, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 269 Score: 0.33553611775084424 Params: {'bagging_fraction': 0.899704039279453, 'feature_fraction': 0.7738018591918653, 'lambda_l1': 29.319737056541822, 'max_depth': 16, 'min_data_in_leaf': 90, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 270 Score: 0.33575645570824864 Params: {'bagging_fraction': 0.8637122376692877, 'feature_fraction': 0.8070242944948626, 'lambda_l1': 28.85265722159444, 'max_depth': 16, 'min_data_in_leaf': 89, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 271 Score: 0.33549647524010595 Params: {'bagging_fraction': 0.8885640058274077, 'feature_fraction': 0.7919341008443913, 'lambda_l1': 27.729149598493652, 'max_depth': 16, 'min_data_in_leaf': 90, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 272 Score: 0.35144863011600935 Params: {'bagging_fraction': 0.8584385825440815, 'feature_fraction': 0.8498812383660613, 'lambda_l1': 28.28596851387556, 'max_depth': 16, 'min_data_in_leaf': 35, 'n_estimators': 700, 'num_leaves': 2}
# Eval No: 273 Score: 0.3354614458384235 Params: {'bagging_fraction': 0.8676240824910422, 'feature_fraction': 0.8133847851829318, 'lambda_l1': 29.905924006521097, 'max_depth': 16, 'min_data_in_leaf': 97, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 274 Score: 0.33552527866079074 Params: {'bagging_fraction': 0.8871393051284343, 'feature_fraction': 0.7770690383907277, 'lambda_l1': 27.003728556477228, 'max_depth': 16, 'min_data_in_leaf': 69, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 275 Score: 0.33514618907754057 Params: {'bagging_fraction': 0.8478382410329313, 'feature_fraction': 0.8284771126795772, 'lambda_l1': 29.38333201647085, 'max_depth': 16, 'min_data_in_leaf': 21, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 276 Score: 0.33552438845139543 Params: {'bagging_fraction': 0.8992732303843212, 'feature_fraction': 0.8283815325305857, 'lambda_l1': 29.050799197335028, 'max_depth': 16, 'min_data_in_leaf': 147, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 277 Score: 0.3363653583142685 Params: {'bagging_fraction': 0.8772947920171145, 'feature_fraction': 0.7633041582139952, 'lambda_l1': 10.999082633063445, 'max_depth': 16, 'min_data_in_leaf': 104, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 278 Score: 0.3355550383446463 Params: {'bagging_fraction': 0.8996048648568105, 'feature_fraction': 0.7868195923923942, 'lambda_l1': 29.940155292147956, 'max_depth': 16, 'min_data_in_leaf': 21, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 279 Score: 0.33677552669509314 Params: {'bagging_fraction': 0.8818313223322514, 'feature_fraction': 0.8751852581577607, 'lambda_l1': 12.07626880644183, 'max_depth': 16, 'min_data_in_leaf': 94, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 280 Score: 0.3351631297987506 Params: {'bagging_fraction': 0.8560614457849536, 'feature_fraction': 0.7993330309892885, 'lambda_l1': 29.397966004124957, 'max_depth': 16, 'min_data_in_leaf': 128, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 281 Score: 0.33545224251494987 Params: {'bagging_fraction': 0.8551269242222773, 'feature_fraction': 0.7546445812888893, 'lambda_l1': 29.52458044169375, 'max_depth': 16, 'min_data_in_leaf': 128, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 282 Score: 0.3358283502270798 Params: {'bagging_fraction': 0.842562471161455, 'feature_fraction': 0.7376937331863036, 'lambda_l1': 28.16682134866541, 'max_depth': 16, 'min_data_in_leaf': 28, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 283 Score: 0.33573989092024303 Params: {'bagging_fraction': 0.8501021010504419, 'feature_fraction': 0.794190700148098, 'lambda_l1': 29.144270368317112, 'max_depth': 16, 'min_data_in_leaf': 21, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 284 Score: 0.3352948105752511 Params: {'bagging_fraction': 0.8681714764450792, 'feature_fraction': 0.7724436041009783, 'lambda_l1': 28.70183380917899, 'max_depth': 16, 'min_data_in_leaf': 130, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 285 Score: 0.33503317341065286 Params: {'bagging_fraction': 0.8386455578490062, 'feature_fraction': 0.8027915905521918, 'lambda_l1': 27.347647512546786, 'max_depth': 16, 'min_data_in_leaf': 128, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 286 Score: 0.33547748359816987 Params: {'bagging_fraction': 0.8385530805689345, 'feature_fraction': 0.8193305489179189, 'lambda_l1': 29.486461978117454, 'max_depth': 16, 'min_data_in_leaf': 142, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 287 Score: 0.3357807639761303 Params: {'bagging_fraction': 0.8602021306097982, 'feature_fraction': 0.7478715626357013, 'lambda_l1': 27.192422404033405, 'max_depth': 16, 'min_data_in_leaf': 137, 'n_estimators': 700, 'num_leaves': 19}
# Eval No: 288 Score: 0.33569571326417824 Params: {'bagging_fraction': 0.8283920411578986, 'feature_fraction': 0.782564179166056, 'lambda_l1': 26.367529708921314, 'max_depth': 16, 'min_data_in_leaf': 140, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 289 Score: 0.3352656759928401 Params: {'bagging_fraction': 0.8486830322962731, 'feature_fraction': 0.8336088898185126, 'lambda_l1': 27.538375565775258, 'max_depth': 16, 'min_data_in_leaf': 128, 'n_estimators': 700, 'num_leaves': 20}
# Eval No: 290 Score: 0.33709648873383624 Params: {'bagging_fraction': 0.8386219975962411, 'feature_fraction': 0.7653725924689792, 'lambda_l1': 28.690224758326448, 'max_depth': 16, 'min_data_in_leaf': 127, 'n_estimators': 700, 'num_leaves': 8}
# Eval No: 291 Score: 0.3355032832990448 Params: {'bagging_fraction': 0.8651806911296551, 'feature_fraction': 0.8016215149555164, 'lambda_l1': 26.619064147553097, 'max_depth': 16, 'min_data_in_leaf': 82, 'n_estimators': 700, 'num_leaves': 13}
# Eval No: 292 Score: 0.3361416012290188 Params: {'bagging_fraction': 0.8726478791621567, 'feature_fraction': 0.8428132582139898, 'lambda_l1': 29.98331933970818, 'max_depth': 16, 'min_data_in_leaf': 116, 'n_estimators': 700, 'num_leaves': 27}
# Eval No: 293 Score: 0.33537897500734515 Params: {'bagging_fraction': 0.8243620929176054, 'feature_fraction': 0.8138269850675691, 'lambda_l1': 29.9923885641976, 'max_depth': 16, 'min_data_in_leaf': 141, 'n_estimators': 700, 'num_leaves': 14}
# Eval No: 294 Score: 0.33829139491608295 Params: {'bagging_fraction': 0.8328494903967121, 'feature_fraction': 0.7946573696118822, 'lambda_l1': 25.16024813820674, 'max_depth': 16, 'min_data_in_leaf': 64, 'n_estimators': 700, 'num_leaves': 6}
# Eval No: 295 Score: 0.3354502745474707 Params: {'bagging_fraction': 0.8832200064161451, 'feature_fraction': 0.855341765572876, 'lambda_l1': 27.78945154898926, 'max_depth': 9, 'min_data_in_leaf': 128, 'n_estimators': 700, 'num_leaves': 18}
# Eval No: 296 Score: 0.33777157262515534 Params: {'bagging_fraction': 0.8524557640919433, 'feature_fraction': 0.7415948572436124, 'lambda_l1': 29.366629010763184, 'max_depth': 3, 'min_data_in_leaf': 55, 'n_estimators': 700, 'num_leaves': 26}
# Eval No: 297 Score: 0.3408835399237359 Params: {'bagging_fraction': 0.8124141357668724, 'feature_fraction': 0.7303377161528062, 'lambda_l1': 25.962148577983683, 'max_depth': 16, 'min_data_in_leaf': 128, 'n_estimators': 700, 'num_leaves': 4}
# Eval No: 298 Score: 0.3354709332838457 Params: {'bagging_fraction': 0.8560013169538337, 'feature_fraction': 0.7202024319893268, 'lambda_l1': 28.537926026566268, 'max_depth': 13, 'min_data_in_leaf': 26, 'n_estimators': 700, 'num_leaves': 22}
# Eval No: 299 Score: 0.34099635676903584 Params: {'bagging_fraction': 0.8998073876467361, 'feature_fraction': 0.7571600456772791, 'lambda_l1': 27.25214885771468, 'max_depth': 19, 'min_data_in_leaf': 118, 'n_estimators': 100, 'num_leaves': 29}
# Eval No: 300 Score: 0.3364716139513675 Params: {'bagging_fraction': 0.5790125166404003, 'feature_fraction': 0.8224994625312705, 'lambda_l1': 24.56275351186509, 'max_depth': 5, 'min_data_in_leaf': 31, 'n_estimators': 700, 'num_leaves': 18}
# Hyperopt estimated optimum {'bagging_fraction': 0.8938820204303998, 'feature_fraction': 0.8582316318535632, 'max_depth': 13, 'min_data_in_leaf': 70, 'n_estimators': 6, 'num_leaves': 16, 'reg_lambda': 28.278990042794067}
# {'bagging_fraction': 0.8938820204303998, 'feature_fraction': 0.8582316318535632, 'lambda_l1': 28.278990042794067, 'max_depth': 16, 'min_data_in_leaf': 90, 'n_estimators': 700, 'num_leaves': 18}

# %%
# prediction on poly feats
best_params = {'bagging_fraction': 0.8938820204303998,
               'feature_fraction': 0.8582316318535632,
               'lambda_l1': 28.278990042794067,
               'max_depth': 16,
               'min_data_in_leaf': 90,
               'n_estimators': 700,
               'num_leaves': 18}

# model
clf = lgbm.LGBMClassifier(**best_params,
                          learning_rate=0.05,
                         scale_pos_weight=4)
clf.fit(xtrain,ytrain)
preds_train = clf.predict(xtrain)
preds = clf.predict(xval)

print("accuracy on train:",roc_auc_score(ytrain,preds_train))
print("accuracy on val:",roc_auc_score(yval,preds))
# Out:
# /home/quan/anaconda3/envs/fastai/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# accuracy on train: 0.6576876872916599
# accuracy on val: 0.6207292586769982
# /home/quan/anaconda3/envs/fastai/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
# preds on test
preds_test = clf.predict(test_processed_poly)

sub['loan_default'] = preds_test

# save to csv
sub.to_csv("poly not full.csv",index=False)
# Out:
# /home/quan/anaconda3/envs/fastai/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
# fit on entire data set and submit
clf.fit(train_processed_poly,y)

# preds on test
preds_test = clf.predict(test_processed_poly)

sub['loan_default'] = preds_test

# save to csv
sub.to_csv("poly feats full.csv",index=False)
# Out:
# /home/quan/anaconda3/envs/fastai/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
